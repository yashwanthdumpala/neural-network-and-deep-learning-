# %%
#1.a.program to delete at least 2 characters and the resulting string and print it
a=input("enter text: ")
b=a[:4]
print(b[::-1])
# Out:
# enter text: python
# htyp

# %%
#1.b.program to perform 4 arthematic operations on any 2 numbers
a=int(input("enter a number: "))
b=int(input("enter a number: "))
print("addition",a+b)
print("subtract",a-b)
print("multiplication",a*b)
print("division",a/b)
# Out:
# enter a number: 6
# enter a number: 8
# addition 14
# subtract -2
# multiplication 48
# division 0.75

# %%
#2.program that accepts a sentence and replace each occurrence of ‘python’ with 'pythons'
s=input("enter string: ")
k=s.replace("python","pythons")
print("after replacing:",k)
# Out:
# enter string: i want to learn python
# after replacing: i want to learn pythons

# %%
#program to print the letter grade based on an input class score.
m=int(input("enter the marks:" ))
if(m>=90 and m<100):
  print("Grade A")
elif(m>=80 and m<90):
  print("Grade B")
elif(m>=70 and m<80):
  print("Grade C")
elif(m>=60 and m<70):
  print("Grade D")
elif(m>=50 and m<60):
  print("Grade E")
else:
  print("Grade F")
# Out:
# enter the marks:60
# Grade D
